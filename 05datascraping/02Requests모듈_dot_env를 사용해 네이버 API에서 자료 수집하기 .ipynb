# %% [markdown]
# # 1. requests 모듈
# * HTTP프로토콜을 사용할 수 있게 해주는 모듈
# * 파이썬 기본 모듈인 urllib보다 사용이 편리
# * 따로 설치 필요 pip install requests/conda install requests

# %% [markdown]
# # 2. requests 모듈 사용법
# * 1) 모듈 불러오기: import requests
# * 2) url을 변수에 저장
# * 3) url파라미터를 payload 라는 변수에 딕셔너리 형태로 저장
#   * payload = {파라미터1: value, 파라미터2: value2}
# * 4) headers도 headers라는 변수에 딕셔너리 형태로 저장
#   * headers = {파라미터1: value, 파라미터2: value2}
#  * 5) HTTP요청 보내기 get, post
#    * get: r = requests.get(url, params=payload, headers=headers)
#    * post: r = requests.post(url, data={key:value})
# * 6) 만들어진 url 확인: print(r.url)
# * 7) 응답코드확인: print(r.status_code)
# * 8) 응답 요소 출력: r.text, r.content, r.json()

# %%
import requests
url = " "
payload = dict()
r = requests.get(url, params=payload)
print(r.url)
print(r.status_code)
response = r.text, r.content, r.json()
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Cell In[1], line 4
#       2 url = " "
#       3 payload = dict()
# ----> 4 r = requests.get(url, params=payload)
#       5 print(r.url)
#       6 print(r.status_code)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\requests\sessions.py:575, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     562 # Create the Request.
#     563 req = Request(
#     564     method=method.upper(),
#     565     url=url,
#    (...)
#     573     hooks=hooks,
#     574 )
# --> 575 prep = self.prepare_request(req)
#     577 proxies = proxies or {}
#     579 settings = self.merge_environment_settings(
#     580     prep.url, proxies, stream, verify, cert
#     581 )
#
# File ~\miniforge3\envs\fintech\lib\site-packages\requests\sessions.py:484, in Session.prepare_request(self, request)
#     481     auth = get_netrc_auth(request.url)
#     483 p = PreparedRequest()
# --> 484 p.prepare(
#     485     method=request.method.upper(),
#     486     url=request.url,
#     487     files=request.files,
#     488     data=request.data,
#     489     json=request.json,
#     490     headers=merge_setting(
#     491         request.headers, self.headers, dict_class=CaseInsensitiveDict
#     492     ),
#     493     params=merge_setting(request.params, self.params),
#     494     auth=merge_setting(auth, self.auth),
#     495     cookies=merged_cookies,
#     496     hooks=merge_hooks(request.hooks, self.hooks),
#     497 )
#     498 return p
#
# File ~\miniforge3\envs\fintech\lib\site-packages\requests\models.py:367, in PreparedRequest.prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     364 """Prepares the entire request with the given parameters."""
#     366 self.prepare_method(method)
# --> 367 self.prepare_url(url, params)
#     368 self.prepare_headers(headers)
#     369 self.prepare_cookies(cookies)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\requests\models.py:438, in PreparedRequest.prepare_url(self, url, params)
#     435     raise InvalidURL(*e.args)
#     437 if not scheme:
# --> 438     raise MissingSchema(
#     439         f"Invalid URL {url!r}: No scheme supplied. "
#     440         f"Perhaps you meant https://{url}?"
#     441     )
#     443 if not host:
#     444     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
#
# MissingSchema: Invalid URL '': No scheme supplied. Perhaps you meant https://?

# %%
# !conda install requests
# 터미널 가서 해도 됨

# %%
import requests
url = "https://openapi.naver.com/v1/search/blog"
keyword ="핀테크"
payload = dict(query=keyword, display=100, start=1, sort="date")
headers = {"X-Naver-Client-Id" : "id", "X-Naver-Client-Secret" : "pw"} #등호 콜론(:)으로 바꾸는 거 중요
r = requests.get(url, params=payload, headers=headers)
print(r.url)
print(r.status_code)
response = r.json()
response
# Out:
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=date
# 401
# {'errorMessage': 'NID AUTH Result Invalid (1000) : Authentication failed. (인증에 실패했습니다.)',
#  'errorCode': '024'}

# %%
dict(query="keyword", display=100, start=1, sort="date")
# Out:
# {'query': 'keyword', 'display': 100, 'start': 1, 'sort': 'date'}

# %%
print(type(response))
# Out:
# <class 'dict'>

# %%
response['items']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 response['items']
#
# KeyError: 'items'

# %%
#import pandas as pd

# %%
#pd.DataFrame(response['items'])

# %%
import re
def text_clean(text):
    # HTML 태그를 없애는 정규표현식
    result = re.sub(r"</?[^>]+>", "", text)
    # 한글, 영문, 숫자 외의 모든 문자 제거 후 공백으로 변환
    result = re.sub(r"[^가-힣a-zA-Z0-9]", " ", result)
    result = result.replace("  ", " ").replace("  ", " ").replace("  ", " ")
    return result

# %%
result={}
for item in response['items']:
    for key,value in item.items():
        if key in ["title", "description"]:
            result.setdefault(key,[]).append(text_clean(value))
        else:
            result.setdefault(key,[]).append(value)
result
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 2
#       1 result={}
# ----> 2 for item in response['items']:
#       3     for key,value in item.items():
#       4         if key in ["title", "description"]:
#
# KeyError: 'items'

# %%
df = pd.DataFrame(result)
df.to_csv("./data/requests로naver_api데이터수집.csv", index=False, encoding="utf-8-sig")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = pd.DataFrame(result)
#       2 df.to_csv("./data/requests로naver_api데이터수집.csv", index=False, encoding="utf-8-sig")
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # python-dotenv로 api key 안전하게 사용하기
# * .env 파일에 환경변수를 저장하고 python 코드에서 자동으로 불러오는 모듈
# * pip install python-dotenv
# * .env 파일을 만들어서 변수=값 형태로 내용 저장
# ``` python
# from dotenv import load_dotenv
# import os
#
# load_dotenv() # 같은 폴더에 .env 파일이 있을 경우 자동으로 불러옴
# # 환경변수 내용 출력
# user_id = os.getenv("Id")
# user_secret= os.getenv("Secret")
# ```
#
# # .env 경로를 다른 곳으로 주거나 이름을 바꾸고 싶을 때
# * load_dotenv("경로 및 파일명")
# ``` python
# from dotenv import load_dotenv
# import os
#
# load_dotenv(dotenv_path="./data/.env_naver") # ./data 폴더에 .env_naver를 불러올 때
# # 환경변수 내용 출력
# user_id = os.getenv("Id")
# user_secret= os.getenv("Secret")
# ```

# %%
from dotenv import load_dotenv
import os
load_dotenv()
import requests

user_id = os.getenv("Id")
user_secret= os.getenv("Secret")

url = "https://openapi.naver.com/v1/search/blog"
keyword ="핀테크"
payload = dict(query=keyword, display=100, start=1, sort="date")
headers = {"X-Naver-Client-Id" : user_id, "X-Naver-Client-Secret" : user_secret} #등호 콜론(:)으로 바꾸는 거 중요
r = requests.get(url, params=payload, headers=headers)
print(r.url)
print(r.status_code)
response = r.json()
response
# Out:
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=date
# 401
# {'errorMessage': 'Not Exist Client ID : Authentication failed. (인증에 실패했습니다.)',
#  'errorCode': '024'}

# %% [markdown]
# # .env 파일명 바꾸고 싶을 때

# %%
from dotenv import load_dotenv
import os
load_dotenv(dotenv_path="./data/.env")
import requests

user_id = os.getenv("Id")
user_secret= os.getenv("Secret")

url = "https://openapi.naver.com/v1/search/blog"
keyword ="핀테크"
payload = dict(query=keyword, display=100, start=1, sort="date")
headers = {"X-Naver-Client-Id" : user_id, "X-Naver-Client-Secret" : user_secret} #등호 콜론(:)으로 바꾸는 거 중요
r = requests.get(url, params=payload, headers=headers)
print(r.url)
print(r.status_code)
response = r.json()
response
# Out:
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=date
# 200
# {'lastBuildDate': 'Wed, 15 Oct 2025 14:00:33 +0900',
#  'total': 476885,
#  'start': 1,
#  'display': 100,
#  'items': [{'title': '10/15 암호화폐(크립토): ‘USDC 축’ 모멘텀, 유럽은 MiCA... ',
#    'link': 'https://blog.naver.com/rockj3/224042009779',
#    'description': '은행·<b>핀테크</b>·거대 상거래와의 파트너링이 수요의 내구성을 결정한다는 점에서, 기관 리서치의 포커스는 타당해 보입니다. 둘째, 감독 일관성은 유럽에서 특히 중요합니다. 국가별 감독 편차를 줄이는... ',
#    'bloggername': '부(富)의 길',
#    'bloggerlink': 'blog.naver.com/rockj3',
#    'postdate': '20251015'},
#   {'title': '농협 햇살론뱅크 조건과 신청방법 후기 확인하기',
#    'link': 'https://sibauchi.tistory.com/1132',
#    'description': '그리고 <b>핀테크</b> 기업의 경쟁 심화라는 복합적인 요인으로 인해 끊임없이 변화해왔습니다. 특히, 금리 인상은 대출 문턱을 높여 저신용, 저소득층의 자금 접근성을 악화시키는 주요 원인이 되었습니다. <b>핀테크</b>... ',
#    'bloggername': "Falconer's Teatime :: 이제는 말하고 말겠다-라멘토 비평",
#    'bloggerlink': 'https://sibauchi.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '오브웰스 사기 TRENUE 금상장 거래 리딩방의 위험한 유혹 (사칭)',
#    'link': 'https://blog.naver.com/crnivorous20772/224041904297',
#    'description': '(사칭) #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#    'bloggername': '데이 강민성 변호사',
#    'bloggerlink': 'blog.naver.com/crnivorous20772',
#    'postdate': '20251015'},
#   {'title': '퍼플버블 사기 purplebubble 쇼핑몰 팀미션 부업의 함정... ',
#    'link': 'https://blog.naver.com/clevelnd42758/224041996021',
#    'description': '(사칭) #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#    'bloggername': 'clevelnd42758님의 블로그',
#    'bloggerlink': 'blog.naver.com/clevelnd42758',
#    'postdate': '20251015'},
#   {'title': '금융의 미래, 디지털 자산이 가져올 혁신 기회와 과제',
#    'link': 'https://blog.naver.com/miracle1024_/224040778473',
#    'description': 'KB금융그룹과 신한은행이 <b>핀테크</b> 스타트업과 협력해 새로운 금융 서비스를 개발하는 것처럼, 대형 금융기관과 혁신 기업 간의 경쟁과 협력이 심화될 것입니다. 또한, 탈중앙화 금융(DeFi)과 중앙은행 디지털화폐... ',
#    'bloggername': '기업운영자금상담',
#    'bloggerlink': 'blog.naver.com/miracle1024_',
#    'postdate': '20251015'},
#   {'title': '퍼플버블 사기 purplebubble 사칭 팀미션부업 이렇게... ',
#    'link': 'https://blog.naver.com/ltent87784/224041999531',
#    'description': '대처하세요 #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문... ',
#    'bloggername': 'daylaw 강민성 대표 변호사',
#    'bloggerlink': 'blog.naver.com/ltent87784',
#    'postdate': '20251015'},
#   {'title': 'BDC 주식 관련주 테마주 대장주 수혜주 정리',
#    'link': 'https://blog.naver.com/aselstan/224041999273',
#    'description': '현대차: 현대차증권, 현대캐피탈 등 계열사를 통해 모빌리티 분야 스타트업 투자 및 <b>핀테크</b> 지원에... 컴퍼니케이: 벤처캐피탈(VC)사로, AI, 바이오, <b>핀테크</b> 등 혁신 기술 기업에 집중 투자합니다.... ',
#    'bloggername': '아셀',
#    'bloggerlink': 'blog.naver.com/aselstan',
#    'postdate': '20251015'},
#   {'title': '클라우드 뱅킹이란? 미래 금융의 핵심 트렌드',
#    'link': 'https://blog.naver.com/shs040404/224041997745',
#    'description': '초연결 금융 생태계 ㆍ <b>핀테크</b>, 기업, 보험사, 유통사 등이 하나의 클라우드 플랫폼 안에서 연결되어... 은행뿐 아니라 <b>핀테크</b>, 보험, 투자 플랫폼까지 모두 클라우드 중심으로 재편되고 있으며, 이는 결국 더... ',
#    'bloggername': '지훈맘의 일상에서의 다양한 정보 이야기',
#    'bloggerlink': 'blog.naver.com/shs040404',
#    'postdate': '20251015'},
#   {'title': '빅데이터 시대, 국비지원으로 데이터 분석가의 길을 열다',
#    'link': 'https://blog.naver.com/kkdh0083/224041996046',
#    'description': '<b>핀테크</b>와 금융 시장 은행, 카드사, 보험사에서는 고객의 소비 패턴과 신용도를 분석해 맞춤형 금융 상품을 개발합니다. 사기 거래 탐지, 투자 예측, 리스크 관리 등에서 데이터분석은 필수적인 도구가... ',
#    'bloggername': 'IT Career Guide: 준비부터 성공까지',
#    'bloggerlink': 'blog.naver.com/kkdh0083',
#    'postdate': '20251015'},
#   {'title': '루나 이후 3년, 한국이 다시 약속을 쓴다 — 스테이블코인... ',
#    'link': 'https://blog.naver.com/make_second_salary/224041990912',
#    'description': '은행 중심 발행만 허용하면 시장 경쟁이 막히고 <b>핀테크</b> 기업의 성장 기회가 사라진다고 본다. 두... 결제·<b>핀테크</b> 인프라 보유 카카오뱅크·페이 연계 결제망 확대 수혜 비덴트 업비트 최대주주... ',
#    'bloggername': '재테크요원의 Second Salary HQ',
#    'bloggerlink': 'blog.naver.com/make_second_salary',
#    'postdate': '20251015'},
#   {'title': '2. 카카오뱅크',
#    'link': 'https://blog.naver.com/hero1197/224041981318',
#    'description': '카카오뱅크 시작하며: 디지털 은행의 가능성, 그 핵심 주자 <b>핀테크</b>, 디지털 뱅킹 바람 속에서... #카카오뱅크 #KakaoBank #디지털뱅크 #인터넷전문은행 #<b>핀테크</b> #모바일뱅킹 #금융플랫폼 #카카오 #디지털금융... ',
#    'bloggername': 'IM DABABA 컨설팅',
#    'bloggerlink': 'blog.naver.com/hero1197',
#    'postdate': '20251015'},
#   {'title': '다날 주가 분석 및 향후 전망 – 투자 전략 가이드',
#    'link': 'https://blog.naver.com/gaogaiga13/224041058636',
#    'description': '디지털 금융과 <b>핀테크</b> 시장이 성장하는 가운데 안정적인 수익 구조와 다양한 신사업 진출로... 글로벌 <b>핀테크</b> 트렌드 호재와 함께 투자자 관심이 집중되었습니다. 다만 2025년 상반기에는 경기 변동과 국내외... ',
#    'bloggername': '3년1억',
#    'bloggerlink': 'blog.naver.com/gaogaiga13',
#    'postdate': '20251015'},
#   {'title': '리플(XRP) : 은행형 블록체인',
#    'link': 'https://blog.naver.com/skehlsek0103/224041978696',
#    'description': '리플은 단순히 코인을 파는 회사가 아니라, 금융 인프라를 판매하는 B2B <b>핀테크</b> 기업이야. 정확히... 리플은 단순히 코인을 파는 회사가 아니라, 금융 인프라를 판매하는 B2B <b>핀테크</b> 기업이야. 정확히... ',
#    'bloggername': '사부아 비부르 삶을 꿈꾸다',
#    'bloggerlink': 'blog.naver.com/skehlsek0103',
#    'postdate': '20251015'},
#   {'title': '카카오뱅크 비상금대출 연체 후 대처방법 확인',
#    'link': 'https://sibauchi.tistory.com/1146',
#    'description': '또한, <b>핀테크</b> 기업들은 금리 인상에 대응하여 리스크 관리 시스템을 강화하고, 다양한 상환 방식을 제공하는 등 적극적인 전략을 펼칠 것으로 보입니다. 소비자들은 고금리 시대에 맞춰 소비 습관을 재점검하고... ',
#    'bloggername': "Falconer's Teatime :: 이제는 말하고 말겠다-라멘토 비평",
#    'bloggerlink': 'https://sibauchi.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '퍼플버블 사기 쇼핑몰 팀미션 부업 믿음으로 유도된... ',
#    'link': 'https://blog.naver.com/frngible82663/224041963463',
#    'description': '(사칭) #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#    'bloggername': 'daylaw 강민성 대표 변호사',
#    'bloggerlink': 'blog.naver.com/frngible82663',
#    'postdate': '20251015'},
#   {'title': '2025년 10월 15일 - 16일 미국주식정보(25.10.15... ',
#    'link': 'https://blog.naver.com/wnguddhkd/224041961763',
#    'description': '첨부파일 10.15 미국 트럼프, 중국에 대두 수입 중단 경고. 연준 파월 의장은 양적긴축 종료 시사 등.pdf 첨부파일 TDAGeneric_NAM_10152025.pdf $ASML $BAC $DLTR $KARO $EQBK $HWC $MS $PGR $SYF $ABT $PLD $CFG $FHN $PNC... ',
#    'bloggername': '호기심',
#    'bloggerlink': 'blog.naver.com/wnguddhkd',
#    'postdate': '20251015'},
#   {'title': "&quot;'10초 이체' 카카오뱅크 vs '10분 로딩' 은행 앱, 이 차이는... ",
#    'link': 'https://blog.naver.com/opopjknm/224041958862',
#    'description': '&quot;아, 진짜! 로그인만 5분째네!&quot; &quot;공인인증서 비번 뭐였지? 보안카드 어디 갔어!&quot; 여러분, 은행 앱 한번 쓰려다가 혈압 올라서 뒷목 잡았던 경험, 다들 있으시죠?  분명 내 돈 내가 쓰겠다는데, 온갖 인증 절차와... ',
#    'bloggername': '오늘의 트렌드픽',
#    'bloggerlink': 'blog.naver.com/opopjknm',
#    'postdate': '20251015'},
#   {'title': '전북은행 비상금대출 신청자격과 한도조건 정리',
#    'link': 'https://sibauchi.tistory.com/1092',
#    'description': '<b>핀테크</b> 기업들의 공격적인 마케팅과 간편한 대출 서비스는 전통적인 은행의 경쟁력을 위협하며 시장의... 주요 은행들은 디지털 전환을 가속화하고, <b>핀테크</b> 기업과의 협력을 통해 새로운 고객 확보 전략을... ',
#    'bloggername': "Falconer's Teatime :: 이제는 말하고 말겠다-라멘토 비평",
#    'bloggerlink': 'https://sibauchi.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '와타나베 부인 – 미국주식으로 우아한 할머니 되기',
#    'link': 'https://blog.naver.com/33mom_invest/224041954018',
#    'description': 'AI · 반도체 · 빅테크 <b>핀테크</b> · 블록체인 혁신기술 · 양자컴퓨터 정책이 곧 돈의 방향이다. 누가 잘 될까보다, 어디에 돈이 몰리는가를 봐야 한다. ② ETF로 분산투자하자 ETF는 여러 종목이 담긴 바구니다.... ',
#    'bloggername': '개미아줌마 투자기록장',
#    'bloggerlink': 'blog.naver.com/33mom_invest',
#    'postdate': '20251015'},
#   {'title': '리얼리뷰 사기 사칭 팀미션 피해회복 이것만은 꼭 알아두세요',
#    'link': 'https://blog.naver.com/emsculte79299/224041947818',
#    'description': '알아두세요 #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#    'bloggername': 'daylaw 강민성 대표 변호사',
#    'bloggerlink': 'blog.naver.com/emsculte79299',
#    'postdate': '20251015'},
#   {'title': '8등급 대출 재대출 가능한 조건과 승인사례 공유',
#    'link': 'https://sibauchi.tistory.com/1135',
#    'description': '반면, <b>핀테크</b> 기업들은 빅데이터 기반의 신용평가 모델을 도입하여 틈새시장을 공략하고 있으며, 대출... 전문가들은 정부의 적극적인 금융 지원 정책과 함께, <b>핀테크</b> 기업들의 혁신적인 신용평가 모델 도입이... ',
#    'bloggername': "Falconer's Teatime :: 이제는 말하고 말겠다-라멘토 비평",
#    'bloggerlink': 'https://sibauchi.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '국내외 양자컴퓨터 관련주 실적 및 기술 보유 현황',
#    'link': 'https://blog.naver.com/ohroseshop/224041946031',
#    'description': 'ID Quantique 납품 사례 있음 최근 양자 테마주로 묶이며 일부 주가 급등 있음 아톤 <b>핀테크</b> / 인증 보안 양자내성 암호(ML-DSA) 기술 적용 인증솔루션 개발 발표됨 양자 보안 테마주로 상승세 보임 우리로... ',
#    'bloggername': 'bom의 블로그',
#    'bloggerlink': 'blog.naver.com/ohroseshop',
#    'postdate': '20251015'},
#   {'title': '지금 바로 5만 원 받기! 케이뱅크 송편 뽑기 정답 총정리 (10월... ',
#    'link': 'https://blog.naver.com/rlaqudcjf338/224041944677',
#    'description': '2025년 모바일 뱅킹 트렌드 분석 디지털 금융 시장 변화 올해 <b>핀테크</b> 업계는 고객 확보를 위한 경쟁이 더욱 치열해졌습니다. 카카오뱅크, 토스 뱅크, 케이뱅크 등 주요 인터넷 전문 은행들이 다양한 마케팅... ',
#    'bloggername': '소확행',
#    'bloggerlink': 'blog.naver.com/rlaqudcjf338',
#    'postdate': '20251015'},
#   {'title': '대학생 대출 신청조건과 금리 비교 총정리',
#    'link': 'https://think-tank.tistory.com/885',
#    'description': '<b>핀테크</b> 기업의 등장으로 인해 대출 상품이 더욱 다양해지고, 대출 신청 절차가 더욱 간편해질 것입니다. 또한, 인공지능(AI)을 활용한 대출 심사 시스템이 도입되어 대출 심사의 정확성이 높아질 것입니다.... ',
#    'bloggername': 'think-tank.tistory.com',
#    'bloggerlink': 'https://think-tank.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '미래 지향적 주식 투자 추천 믿거나 말거나',
#    'link': 'https://blog.naver.com/eyhs80/224041939801',
#    'description': '---  5️⃣ 데이터·<b>핀테크</b>·디지털 자산 핵심 이유: 블록체인 기반 결제·자산 토큰화, AI금융이 새로운 금융질서로 이동. 관련 주식:  Coinbase, Block(Square), PayPal, Palantir https://link.coupang.... ',
#    'bloggername': '정보는 본느 좋은 정보',
#    'bloggerlink': 'blog.naver.com/eyhs80',
#    'postdate': '20251015'},
#   {'title': '장기카드대출 빨리 철회하고 신용점수 올리기 (NICE KCB)',
#    'link': 'https://blog.naver.com/blenakorea/224041936463',
#    'description': '또한, 별도의 서류 제출 없이 <b>핀테크</b> 앱(네이버페이, 토스 등)을 통해 간편하게 납부내역을 제출할 수 있으니 적극 활용하시길 권장합니다. 3. 카드대금 선결제 결제일 전에 미리 납부하는 선결제는 신용점수... ',
#    'bloggername': '이룸금융센터 Partner밥팀장',
#    'bloggerlink': 'blog.naver.com/blenakorea',
#    'postdate': '20251015'},
#   {'title': '신한 쏠편한 비상금대출 신청 절차와 실제 이용 후기',
#    'link': 'https://sibauchi.tistory.com/1112',
#    'description': '강화, <b>핀테크</b> 기업의 적극적인 참여 등 다양한 요인으로 인해 역동적인 변화를 겪었습니다. 특히 금리 인상은 소비자들의 대출 부담을 가중시켰고, 정부의 대출 규제는 대출 문턱을 높였습니다. 반면, <b>핀테크</b>... ',
#    'bloggername': "Falconer's Teatime :: 이제는 말하고 말겠다-라멘토 비평",
#    'bloggerlink': 'https://sibauchi.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '마이데이터 사업자라면 꼭 알아야 할 법률 적용 기준',
#    'link': 'https://blog.naver.com/byunbyun_law/224041919942',
#    'description': '#마이데이터 #MyData #개인정보보호법 #신용정보법 #개인정보위원회 #특수전문기관 #일반전문기관 #데이터전송요구권 #데이터활용 #데이터산업 #<b>핀테크</b> #데이터법제 #정보보호 #데이터정책 #마이데이터사업자... ',
#    'bloggername': '최변과 변변의 법률 서재',
#    'bloggerlink': 'blog.naver.com/byunbyun_law',
#    'postdate': '20251015'},
#   {'title': '성남채무자신용조사 변호사 상담 전 확인해야 할 체크리스트',
#    'link': 'https://blog.naver.com/appropriate5g/224041919785',
#    'description': '예를 들어, 한 <b>핀테크</b> 기업이 성남채무자신용조사에 AI를 적용해서 고객의 재무 상태를 실시간으로 분석하는 서비스로 경쟁력을 강화하고 있습니다. 이 경우, 요청자는 간편하게 신용 조사를 받을 수 있고... ',
#    'bloggername': '은하수여행',
#    'bloggerlink': 'blog.naver.com/appropriate5g',
#    'postdate': '20251015'},
#   {'title': '“네·카·토 지분 쥔 증권사들… 스테이블코인 수혜... ',
#    'link': 'https://blog.naver.com/bamnatowl/224041919964',
#    'description': '그런데 이 세 <b>핀테크</b> 플랫폼 기업들의 지분을 보유한 증권사들이 주목받고 있다는 사실, 알고... 23% 보유 이처럼 국내 대표 증권사들이 ‘네·카·토’ <b>핀테크</b> 계열사에 상당한 지분을 가지고 있습니다.... ',
#    'bloggername': '헤베다',
#    'bloggerlink': 'blog.naver.com/bamnatowl',
#    'postdate': '20251015'},
#   {'title': '근로장려금 수급자를 위한 맞춤형 대출 종류 총정리',
#    'link': 'https://think-tank.tistory.com/907',
#    'description': '강화, <b>핀테크</b> 기업의 등장 등 다양한 요인으로 인해 빠르게 변화하고 있습니다. 특히, 저금리 시대가... 또한, <b>핀테크</b> 기업들은 빅데이터 분석과 AI 기술을 활용하여 개인별 맞춤형 대출 상품을 추천하고, 온라인... ',
#    'bloggername': 'think-tank.tistory.com',
#    'bloggerlink': 'https://think-tank.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '똑똑한 해외송금, 지머니트랜스 파헤치기: 수수료 절약 노하우',
#    'link': 'https://blog.naver.com/mm_yooni/224041912905',
#    'description': '지머니트랜스는 금융위원회에 정식 등록된 합법적인 해외송금 <b>핀테크</b> 기업으로, 고객 자금을 회사... #해외송금, #지머니트랜스, #송금수수료, #해외송금꿀팁, #<b>핀테크</b>, #환율, #자산관리, #유학생송금, #해외생활비... ',
#    'bloggername': '브랜드메이커 유니',
#    'bloggerlink': 'blog.naver.com/mm_yooni',
#    'postdate': '20251015'},
#   {'title': '루민트, 금융 산업의 신뢰를 재정의하는 블록체인 데이터 인프라',
#    'link': 'https://blog.naver.com/mecca_edu_/224041909451',
#    'description': '금융 데이터 거버넌스 혁신 루민트는 금융기관 간 데이터 연동 플랫폼을 통해 은행·보험·<b>핀테크</b> 간 데이터 공유의 효율성을 높이고 있습니다. 중앙 관리 없이도 신뢰를 유지할 수 있는 분산형 구조가 금융... ',
#    'bloggername': 'km님의 블로그',
#    'bloggerlink': 'blog.naver.com/mecca_edu_',
#    'postdate': '20251015'},
#   {'title': '리드코프 주부대출 신청조건과 재대출 가능여부 확인',
#    'link': 'https://sibauchi.tistory.com/1128',
#    'description': '강화, <b>핀테크</b> 기업의 등장 등 다양한 요인에 의해 끊임없이 변화해왔습니다. 특히 금리 인상은 대출 상환 부담을 가중시켜 신규 대출 신청을 망설이게 하는 요인으로 작용했습니다. 동시에, <b>핀테크</b> 기업들은... ',
#    'bloggername': "Falconer's Teatime :: 이제는 말하고 말겠다-라멘토 비평",
#    'bloggerlink': 'https://sibauchi.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '개인파산 P2P대출 처리, 어떻게 해야 할까?',
#    'link': 'https://blog.naver.com/weather4092/224041904262',
#    'description': '최근 몇 년간 <b>핀테크</b> 기술 발전하면서 P2P 대출 산업도 빠르게 성장하였습니다. 그러나 경기 침체나 재정 문제로 인해 대출 상환이 어려워진 경우에는 개인 파산을 고려해야 할 수도 있는데요. 이때 P2P 대출을... ',
#    'bloggername': '부자 되는 습관',
#    'bloggerlink': 'blog.naver.com/weather4092',
#    'postdate': '20251015'},
#   {'title': "# 아티클 # 10월 셋째 주 / 2030 투자 트렌드 : '콩알금'에서... ",
#    'link': 'https://blog.naver.com/hyns_blog/224041897717',
#    'description': '<b>핀테크</b>의 무기, ‘소수점·자동·구독형’ 2030세대는 수입과 지출이 일정하지 않기에, ‘조금씩·자주... 증권사는 1주보다 작은 단위로 주식을 살 수 있는 소수점 투자, 은행·<b>핀테크</b>는 라운드업(잔돈 투자)... ',
#    'bloggername': '실무자의 시간을 아껴줄 : BUSINESS STUDY LOUNGE',
#    'bloggerlink': 'blog.naver.com/hyns_blog',
#    'postdate': '20251015'},
#   {'title': '웰컴저축은행 자동대출 신청자격과 이용절차 안내',
#    'link': 'https://think-tank.tistory.com/912',
#    'description': '강화, <b>핀테크</b> 기업의 성장 등 다양한 요인에 의해 큰 변화를 겪었습니다. 특히, 고금리 시대에... <b>핀테크</b> 기업들은 인공지능(AI) 기반의 신용 평가 모델을 도입하여 리스크 관리를 강화하고, 맞춤형 대출 상품을... ',
#    'bloggername': 'think-tank.tistory.com',
#    'bloggerlink': 'https://think-tank.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '양자컴퓨터 관련주 완벽 정리',
#    'link': 'https://blog.naver.com/ohroseshop/224041895869',
#    'description': '아톤 <b>핀테크</b> 보안 솔루션 양자 보안 결제 인증 연구 금융권 양자보안 적용 기대 우리넷 네트워크 장비 양자암호 기반 네트워크 실증 사업 참여 공공기관 연계 사업 강점  요약: 국내 기업들은... ',
#    'bloggername': 'bom의 블로그',
#    'bloggerlink': 'blog.naver.com/ohroseshop',
#    'postdate': '20251015'},
#   {'title': '루민트의 글로벌 전략, 상장을 넘어 세계로',
#    'link': 'https://blog.naver.com/call1128/224041893901',
#    'description': '파트너십 확대 현재 루민트는 유럽, 일본, 동남아 등지의 <b>핀테크</b> 기업들과 기술 제휴 협상을 진행 중입니다. 이는 상장 이후 ‘사용성 확장’을 위한 포석입니다. 6. 글로벌 신뢰 구축 루민트는 프로젝트... ',
#    'bloggername': 'call1128님의 블로그',
#    'bloggerlink': 'blog.naver.com/call1128',
#    'postdate': '20251015'},
#   {'title': '과거 경제위기가 남긴 교훈과 우리가 배워야 할 것들',
#    'link': 'https://blog.naver.com/homeros_finvalue/224041892519',
#    'description': '2008년 이후는 <b>핀테크</b>와 플랫폼 금융이 등장한 시기였고, 2020년 이후는 비대면 산업, 원격 근무, 디지털 전환이 가속화되었죠. 경제는 무너진 자리에 새로운 질서를 만들며 회복해왔습니다. 우리에게 필요한... ',
#    'bloggername': '호숫가(호메로스의 숫자 너머의 가치)',
#    'bloggerlink': 'blog.naver.com/homeros_finvalue',
#    'postdate': '20251015'},
#   {'title': '신용회복위원회 비대면 간편대출 자격과 조건 확인',
#    'link': 'https://sibauchi.tistory.com/1102',
#    'description': '<b>핀테크</b> 기업의 성장 등 다양한 요인에 의해 크게 변화했습니다. 특히, 고금리 시대에 접어들면서 대출 문턱이 높아지고, 서민 경제의 어려움이 가중되면서 정책 금융의 역할이 더욱 중요해졌습니다. <b>핀테크</b>... ',
#    'bloggername': "Falconer's Teatime :: 이제는 말하고 말겠다-라멘토 비평",
#    'bloggerlink': 'https://sibauchi.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '네이버 두나무 빅딜 국내 IT판 뒤흔든 진짜 이유',
#    'link': 'https://blog.naver.com/healthfine/224041889884',
#    'description': '이 데이터를 블록체인 기반 결제 시스템과 연결한다면 “한국형 <b>핀테크</b> 슈퍼앱”으로 진화할 가능성도... AI와 블록체인이 결합하면 <b>핀테크</b>의 중심이 카카오에서 네이버로 이동할 가능성이 큽니다. 다만 규제... ',
#    'bloggername': '머니컴컴님의 블로그',
#    'bloggerlink': 'blog.naver.com/healthfine',
#    'postdate': '20251015'},
#   {'title': '2025년 2차 스마트혁신제품 제조기업 기술지원 프로그램 통합... ',
#    'link': 'https://blog.naver.com/hsyae_2000/224041889032',
#    'description': '스마트팜, <b>핀테크</b>, 로봇, 인공지능(AI), 탄소중립) ㅇ (지원대상) 스마트혁신제품을 개발하고자 하는 벤처·중소기업 or 스타트업기업, 1인 창업가 등 ㅇ (지원내용) 스마트혁신제품 제조기업의... ',
#    'bloggername': 'Biz deliverer',
#    'bloggerlink': 'blog.naver.com/hsyae_2000',
#    'postdate': '20251015'},
#   {'title': '월드코인 투자 광풍: 에이트코 홀딩스 주가 3000% 폭등... ',
#    'link': 'https://blog.naver.com/leejh339/224041404223',
#    'description': '그러나 시대의 흐름에 발맞춰 <b>핀테크</b>와 디지털 전환을 추진하며 사업 모델에 변화를 모색하고 있었죠. 그러던 중, 회사는 자사의 재무 준비 자산으로 월드코인을 대량 매입하겠다는 파격적인 결정을... ',
#    'bloggername': 'Today Info',
#    'bloggerlink': 'blog.naver.com/leejh339',
#    'postdate': '20251015'},
#   {'title': 'NFC 기술 특허, 후발주자의 모방을 막는 유일한 방법',
#    'link': 'https://blog.naver.com/vonpatent_/224040494832',
#    'description': '특허법인 본은 ICT, <b>핀테크</b>, IoT 분야에 대한 깊은 이해와 풍부한 등록 성공 경험을 바탕으로, 귀사의 보이지 않는 기술력이 시장에서 가장 강력한 자산이 될 수 있도록 모든 과정을 함께합니다. 귀사의 미래... ',
#    'bloggername': '특허법인 본 IP상담센터 :: 02-6494-0524 ::',
#    'bloggerlink': 'blog.naver.com/vonpatent_',
#    'postdate': '20251015'},
#   {'title': '리얼리뷰 사기 부업 팀미션의 전형적 수법과 실전 대처법 (사칭)',
#    'link': 'https://blog.naver.com/dissocition12385/224041886196',
#    'description': '(사칭) #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#    'bloggername': 'daylaw 강민성 대표 변호사',
#    'bloggerlink': 'blog.naver.com/dissocition12385',
#    'postdate': '20251015'},
#   {'title': '이르면 이달 공개…‘원화 스테이블코인 정부안’ 윤곽 드러난다',
#    'link': 'https://blog.naver.com/926928/224041702016',
#    'description': '3️⃣ 업계 시범사업과 민간 참여 <b>핀테크</b>, 은행, 블록체인 기업들은 정부안 공개를 앞두고 시범... 12) #스테이블코인 #원화스테이블코인 #가상자산법 #금융위원회 #담보관리 #준비금공시 #결제혁신 #<b>핀테크</b>... ',
#    'bloggername': '영종도 라이프: 서울 탈출기',
#    'bloggerlink': 'blog.naver.com/926928',
#    'postdate': '20251015'},
#   {'title': 'AI 중심 경영으로 리셋하는 카카오',
#    'link': 'https://blog.naver.com/jasonsys/224041849267',
#    'description': '기술 중심으로의 회귀, 그리고 신뢰의 재구축 카카오는 한때 기술 기업보다는 콘텐츠·모빌리티·<b>핀테크</b> 등 다양한 영역에 손을 뻗은 복합 플랫폼 그룹으로 인식됐습니다. 그러나 먹통 사태, 계열사 논란, NFT... ',
#    'bloggername': 'JASON',
#    'bloggerlink': 'blog.naver.com/jasonsys',
#    'postdate': '20251015'},
#   {'title': '리얼리뷰 사기 부업 팀미션 교묘한 후기조작의 덫을... ',
#    'link': 'https://blog.naver.com/crnivorous20772/224041883737',
#    'description': '(사칭) #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#    'bloggername': '데이 강민성 변호사',
#    'bloggerlink': 'blog.naver.com/crnivorous20772',
#    'postdate': '20251015'},
#   {'title': '[해유탐 2] 포화 속 눈부신 성과 <b>핀테크</b>-IT 그룹...우크라 첫... ',
#    'link': 'https://blog.naver.com/unicorntimes/224041885569',
#    'description': '#모노뱅크 #우크라이나 #전쟁 #<b>핀테크</b> #토스 #카카오페이 #앱 #네오뱅크 #인터넷전용은행 #<b>핀테크</b>-IT그룹 #미국의회 #UMAEF',
#    'bloggername': '유니콘타임스',
#    'bloggerlink': 'blog.naver.com/unicorntimes',
#    'postdate': '20251015'},
#   {'title': '2025 대환대출 금리 비교 및 신청 가이드｜금리 낮추는... ',
#    'link': 'https://blog.naver.com/motokim08/224041883868',
#    'description': '2025년 현재, 은행 및 금융기관, <b>핀테크</b> 앱을 통해 다양한 대환대출 상품이 제공되고 있으며, 신용점수, 상환능력, 직업 등에 따라 조건이 달라질 수 있으므로 꼼꼼한 비교가 필수입니다. 대환대출이 필요한... ',
#    'bloggername': '베짱이와 방앗간: 문화·금융·IT 이야기',
#    'bloggerlink': 'blog.naver.com/motokim08',
#    'postdate': '20251015'},
#   {'title': '유망직업 시리즈 #1. 소프트웨어 개발자(Software Developer)',
#    'link': 'https://blog.naver.com/u_hak858/224041881844',
#    'description': 'IT기업 (소프트웨어, 클라우드) 금융·<b>핀테크</b> / 컨설팅 / 공공기관 스타트업 창업 또는... 높으며,특히 <b>핀테크</b>와 헬스케어 IT 분야가 빠르게 성장 중이라고 합니다. 수요와 잠재가능성이 큰... ',
#    'bloggername': '꿈꾸는 호랑몽맘의 유학정보',
#    'bloggerlink': 'blog.naver.com/u_hak858',
#    'postdate': '20251015'},
#   {'title': '신한저축은행 참신한500 대출 조건 자격 한도 알아보기',
#    'link': 'https://think-tank.tistory.com/882',
#    'description': '💰🏦 신한저축은행 참신한500 대출, <b>핀테크</b> 시대의 현명한 선택일까? 최근 고금리 시대가 지속되면서... 경쟁 상품으로는 <b>핀테크</b> 기업의 소액 대출 상품들이 있으며, 이들은 참신한500과 유사한 간편한 절차와... ',
#    'bloggername': 'think-tank.tistory.com',
#    'bloggerlink': 'https://think-tank.tistory.com/',
#    'postdate': '20251015'},
#   {'title': 'AI 쇼핑 시대 도래, 챗GPT 결제 기능이 보여준 진짜 변화는?',
#    'link': 'https://blog.naver.com/naknakfishing/224041878228',
#    'description': '이 기술은 오픈AI와 <b>핀테크</b> 기업 스트라이프(Stripe)가 함께 개발했어요. 덕분에 스트라이프를 사용하는 판매자는 코드 한 줄만 추가해도 즉시 결제 기능을 바로 적용할 수 있습니다. 또한 다른 결제... ',
#    'bloggername': '낚시하는 AI강사, 이신영',
#    'bloggerlink': 'blog.naver.com/naknakfishing',
#    'postdate': '20251015'},
#   {'title': 'UIUX 디자이너 되려면? 준비과정과 취업까지',
#    'link': 'https://blog.naver.com/buu5544/224041875738',
#    'description': '주요 취업 분야 IT 대기업(네이버, 카카오 등), 금융/<b>핀테크</b> 기업, 이커머스, 게임, 에듀테크 등 디지털 제품과 서비스를 제공하는 모든 산업에 걸쳐 수요가 폭발적입니다. 특히 스타트업과 디지털... ',
#    'bloggername': 'Yuuum',
#    'bloggerlink': 'blog.naver.com/buu5544',
#    'postdate': '20251015'},
#   {'title': '하나은행 외국인 대출 조건, 신용도별 금리 차이 정리',
#    'link': 'https://ilovefamily.tistory.com/558',
#    'description': '동시에, <b>핀테크</b> 기업의 등장으로 온라인 대출 플랫폼이 활성화되면서 외국인들이 더욱 편리하게 대출... 향후에는 <b>핀테크</b> 기술을 활용한 맞춤형 대출 상품 개발, 인공지능 기반의 신용 평가 시스템 도입, 그리고... ',
#    'bloggername': '과거,현재,미래, 그리고 나.',
#    'bloggerlink': 'https://ilovefamily.tistory.com/',
#    'postdate': '20251015'},
#   {'title': 'Extended 퍼프덱스 에어드랍 작업 가이드 빈집 파밍',
#    'link': 'https://blog.naver.com/cryptocjdcns/224041861740',
#    'description': '유럽 <b>핀테크</b> 기업인 리볼트의 전 경영진들이 빌딩하며 소매 사용자 온보딩과 고성능 거래 인프라 구축이 용이하고 티오가 캐피탈을 리드 투자로 650만 달러 투자 유치도 받았습니다 가장 중요한 포인트... ',
#    'bloggername': '청춘의일상',
#    'bloggerlink': 'blog.naver.com/cryptocjdcns',
#    'postdate': '20251015'},
#   {'title': '⚙️ 2025년 스마트혁신제품 제조기업 기술지원사업! 최대... ',
#    'link': 'https://blog.naver.com/cht__running_mate/224041852553',
#    'description': '스마트공장·시티·팜, <b>핀테크</b>, 로봇, 인공지능(AI), 탄소중립제품 등 ■ 지원내용 요약 이... 바이오헬스지원 #<b>핀테크</b>스타트업 #로봇기술개발 #탄소중립제품 #오픈랩 #R&amp;D랩 #공유오피스지원... ',
#    'bloggername': 'CHT 기업혁신센터',
#    'bloggerlink': 'blog.naver.com/cht__running_mate',
#    'postdate': '20251015'},
#   {'title': '온라인 중고차 혁신 카바나, 파산 위기 딛고 기사회생? CVNA... ',
#    'link': 'https://blog.naver.com/happyjusik/224041852121',
#    'description': '파괴하는 <b>핀테크</b> 혁신 기업입니다. 역대급 실적과 GPU 개선을 통해 수익성을 입증했습니다.  주가... #카바나주가전망 #CVNA주식 #온라인중고차 #중고차딜러사 #<b>핀테크</b>혁신 #주식상위노출 #GPU개선 #파산위기극복... ',
#    'bloggername': 'happyjusik님의 블로그',
#    'bloggerlink': 'blog.naver.com/happyjusik',
#    'postdate': '20251015'},
#   {'title': '현대카드 면접 후기 현대커머셜 직무 PT 토의',
#    'link': 'https://blog.naver.com/bashinga197939/224041844775',
#    'description': '최근 <b>핀테크</b> 확산이 카드산업에 미치는 영향 신규 고객 확보를 위한 차별화 전략 제시 협업 과정에서 겪었던 어려움과 해결 경험 금융산업 종사자로서 가져야 할 덕목은? 실패했던 경험에서 배울 수 있었던 점... ',
#    'bloggername': '바로코칭 채정전',
#    'bloggerlink': 'blog.naver.com/bashinga197939',
#    'postdate': '20251015'},
#   {'title': '모바일 소액대출 여성 무직자 주부 일용직 프리랜서 24시간... ',
#    'link': 'https://blog.naver.com/gonggam98/224041843743',
#    'description': '여러 금융사의 모바일 소액대출 조건을 비교하는 과정에서 ‘대출 실행 총비용 계산 서’를 요청하기도 했는데, 표면상 8% 초반 금리를 제시하던 <b>핀테크</b> 업체들도 보증 보험료 2%, 플랫폼 수수료 등을 포함하면... ',
#    'bloggername': '나무간판 /나무입간판 /LED간판 제작업체',
#    'bloggerlink': 'blog.naver.com/gonggam98',
#    'postdate': '20251015'},
#   {'title': '국민은행 단기카드대출 금리조건과 한도 알아보기',
#    'link': 'https://ilovefamily.tistory.com/517',
#    'description': '주요 카드사들은 데이터 기반 맞춤형 상품 개발과 리스크 관리 강화에 집중하고 있으며, <b>핀테크</b> 기업과의 협력을 통해 새로운 시장 기회를 모색하고 있습니다. 소비자는 금리 변동에 민감하게 반응하며... ',
#    'bloggername': '과거,현재,미래, 그리고 나.',
#    'bloggerlink': 'https://ilovefamily.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '토스뱅크 생활비대출 신청방법과 금리 이용후기 확인',
#    'link': 'https://sibauchi.tistory.com/1108',
#    'description': '<b>핀테크</b> 기업들은 데이터 기반 신용 평가 모델을 고도화하여 리스크 관리를 강화하고, 맞춤형 대출... 주요 은행들은 디지털 전환 가속화와 함께 <b>핀테크</b> 기업과의 협력을 강화하고 있습니다. 카카오뱅크는 생활... ',
#    'bloggername': "Falconer's Teatime :: 이제는 말하고 말겠다-라멘토 비평",
#    'bloggerlink': 'https://sibauchi.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '금융의 역할과 중요성: 현대 사회 경제 발전 핵심 동력',
#    'link': 'https://blog.naver.com/permanfaen6656/224041833835',
#    'description': '모바일 뱅킹이나 온라인 증권 거래, <b>핀테크</b> 서비스 같은 혁신적인 기술이 금융과 결합하면서, 누구나... 뱅킹, <b>핀테크</b>, 온라인 증권 거래 개인 재무 계획 지원 노후 대비, 긴급 자금 관리 결국 금융은 우리 사회와... ',
#    'bloggername': '콘스탄티누스 대제',
#    'bloggerlink': 'blog.naver.com/permanfaen6656',
#    'postdate': '20251015'},
#   {'title': '파가야 테크놀로지스 +6.76% 급등! 그 이유는!? (PGY)',
#    'link': 'https://blog.naver.com/lynkimbobo/224041832145',
#    'description': '또한 가이던스를 상향했는데요, 최근 <b>핀테크</b> 흐름이 안좋았던 이유는 업스타트의 연체율 관련 뉴스... 아니고요, <b>핀테크</b> 전체적으로 수급 부재로 인한 과매도 구간이라서 매수 기회라고 생각하긴 합니다! 다만... ',
#    'bloggername': '주갈남(월급을 주식에 갈아버린 남자)',
#    'bloggerlink': 'blog.naver.com/lynkimbobo',
#    'postdate': '20251015'},
#   {'title': '안성시형사사건변호사 전략적인 대응이',
#    'link': 'https://blog.naver.com/hhnpoll/224041828453',
#    'description': '2전자 금융 거래법의 이해 전자 금융 거래법은 우리가 거래를 할 때 지켜야 할 법률이에요<b>핀테크</b>와 같은 새 금융 거래 방식이 생김에 따라 이런 법이 필요하게 되었죠법은 사용자 보호를 위해 마련된 것이지만... ',
#    'bloggername': '푸른숲의요정',
#    'bloggerlink': 'blog.naver.com/hhnpoll',
#    'postdate': '20251015'},
#   {'title': '[가지급금③] 실제 컨설팅 사례로 보는 가지급금 해결 효과... ',
#    'link': 'https://blog.naver.com/dudals88/224041824272',
#    'description': '서울<b>핀테크</b>랩 멘토 ※ 안내 말씀 ※ 최근 컨설팅 문의가 예년보다 크게 늘어나 답변이 다소 지연될 수 있습니다. 기다려 주신 만큼, 한 분 한 분께 진심을 담아 답변드리겠습니다. 언제나 믿고 찾아주셔서... ',
#    'bloggername': '세금과 친해지는 첫 발걸음, 조영민세무회계',
#    'bloggerlink': 'blog.naver.com/dudals88',
#    'postdate': '20251015'},
#   {'title': '키위 비상금대출 신청방법과 후기 및 금리 확인',
#    'link': 'https://think-tank.tistory.com/883',
#    'description': '특히, <b>핀테크</b> 기업들의 적극적인 시장 참여는 기존 금융기관과의 경쟁을 더욱 치열하게 만들고... 또한, <b>핀테크</b> 기업과의 협력을 통해 더욱 혁신적인 금융 서비스를 제공할 수 있을 것입니다. 소비자들은 이러한... ',
#    'bloggername': 'think-tank.tistory.com',
#    'bloggerlink': 'https://think-tank.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '2금융권 무서류 당일 대출, 현명하게 이용하는 방법: 조건, 후기... ',
#    'link': 'https://blog.naver.com/jkn1318/224041818065',
#    'description': '특히 토스와 같은 <b>핀테크</b> 플랫폼에서는 여러 2금융권의 대출 상품을 한눈에 비교하고 신청할 수 있어 편리합니다. 마치 온라인 쇼핑몰에서 여러 브랜드의 옷을 비교하고 구매하는 것과 같습니다. 가정주부나... ',
#    'bloggername': '조민스토리리',
#    'bloggerlink': 'blog.naver.com/jkn1318',
#    'postdate': '20251015'},
#   {'title': "[단독 분석] 2030년 리플(XRP) 가격 예측: '역대급 폭등'의... ",
#    'link': 'https://blog.naver.com/deanhan84/224041814483',
#    'description': '수많은 은행, 결제 회사, <b>핀테크</b> 기업들이 ODL을 통해 국경 간 거래를 처리하게 되면, XRP에 대한 유동성 수요가 폭발적으로 증가합니다. 이는 XRP의 가격 상승을 넘어 필수 자산으로서의 지위를... ',
#    'bloggername': '건강 재테크 연구소',
#    'bloggerlink': 'blog.naver.com/deanhan84',
#    'postdate': '20251015'},
#   {'title': '디지털화폐 시대 2025, 현금 없는 사회가 바꾸는 우리의 일상',
#    'link': 'https://blog.naver.com/baacakj0652/224041802071',
#    'description': '한국은행은 이미 ‘CBDC(중앙은행 디지털화폐)’ 시범 운영을 확대했고, 민간 금융사와 <b>핀테크</b>... 넷째, <b>핀테크</b> 산업은 디지털화폐 도입으로 새 국면을 맞고 있습니다. 간편결제, 송금, 예적금 관리, 투자 플랫폼... ',
#    'bloggername': '진흥원님의 블로그',
#    'bloggerlink': 'blog.naver.com/baacakj0652',
#    'postdate': '20251015'},
#   {'title': '크라운, 브라질 국채로 뒷받침되는 브라질 헤알... ',
#    'link': 'https://blog.naver.com/nobaedal/224041793169',
#    'description': '상파울루에 본사를 둔 <b>핀테크</b> 기업인 크라운(Crown)은 브라질 정부 채권으로 전액 지원되는... 상파울루의 <b>핀테크</b> 기업 크라운 (Crown)이 브라질 국채로 전액 지원되는 브라질 헤알화 스테이블코 인... ',
#    'bloggername': '코인주식부동산정보',
#    'bloggerlink': 'blog.naver.com/nobaedal',
#    'postdate': '20251015'},
#   {'title': '거시경제 흐름 시리즈 ㊳ AI와 새로운 경제 패러다임 — 기술이... ',
#    'link': 'https://blog.naver.com/knowsomething/224035308391',
#    'description': '펀드, <b>핀테크</b>, 알고리즘 트레이딩  “AI는 효율을 높이지만, 그만큼 인간의 역할을 다시 정의하게 만든다.”  3️⃣ AI가 경제에 미치는 실제 영향 항목 영향 세부 내용  생산성 향상 GDP 성장률 직접 기여... ',
#    'bloggername': '잡다한 지식정보 블로그',
#    'bloggerlink': 'blog.naver.com/knowsomething',
#    'postdate': '20251015'},
#   {'title': '일수대출 재대출 가능여부와 이용 시 주의사항',
#    'link': 'https://sibauchi.tistory.com/1113',
#    'description': '강화, <b>핀테크</b> 기업의 진출 등 다양한 요인으로 인해 변화를 겪었습니다. 금리 인상은 대출 부담을 가중시키고, 규제 강화는 대출 심사를 더욱 꼼꼼하게 만들었습니다. <b>핀테크</b> 기업들은 혁신적인 기술을 바탕으로... ',
#    'bloggername': "Falconer's Teatime :: 이제는 말하고 말겠다-라멘토 비평",
#    'bloggerlink': 'https://sibauchi.tistory.com/',
#    'postdate': '20251015'},
#   {'title': 'GPU 주식 관련주 테마주 대장주 수혜주 정리',
#    'link': 'https://blog.naver.com/aselstan/224041777217',
#    'description': '핑거: 마이데이터 및 블록체인 기반 <b>핀테크</b> 솔루션 개발을 통해 GPU 기반 금융 AI 서비스 연계에 기여합니다. 위세아이텍: AI 기반 빅데이터 분석 및 시각화 솔루션을 제공하여 GPU 기반 시스템의 데이터... ',
#    'bloggername': '아셀',
#    'bloggerlink': 'blog.naver.com/aselstan',
#    'postdate': '20251015'},
#   {'title': '비상금자동적립방법',
#    'link': 'https://blog.naver.com/yflogical/224041767781',
#    'description': '은행이나 증권사, <b>핀테크</b> 앱에서 쉽게 설정할 수 있지요. 이 시스템 덕분에 별도의 노력을 들이지 않아도 저축이나 투자금이 쌓여가는 효과를 볼 수 있습니다. 제가 직접 경험했을 때는 입금일을 신경 쓰지... ',
#    'bloggername': 'yflogical님의 블로그',
#    'bloggerlink': 'blog.naver.com/yflogical',
#    'postdate': '20251015'},
#   {'title': '언번들링-재미있는 경제용어 밀크드롭 23',
#    'link': 'https://blog.naver.com/queendawn/224041766126',
#    'description': '그런데 <b>핀테크</b>(금융+기술) 기업들이 등장하면서, 각 기능이 하나씩 쪼개졌어요. 송금만 빠르고 쉽게 → 토스 해외 송금 전문 → 와이어바알리 대출 비교만 전문 → 핀다 투자 중개 전문 → 카카오페이증권 즉... ',
#    'bloggername': '재미있는 경제용어 매일 즐겁게 행복하게!',
#    'bloggerlink': 'blog.naver.com/queendawn',
#    'postdate': '20251015'},
#   {'title': '부산 비스퀘어빌딩(옛 삼성생명빌딩) 매각 리포트 제공 [부산... ',
#    'link': 'https://blog.naver.com/thekings0104/224041762200',
#    'description': '(참조, 킹스마겐 리서치) - BIFC 권역에서는 U-Space BIFC 프로그램을 통해 <b>핀테크</b>·금융 스타트업에 임대료 지원 인센티브를 제공하고 있으며, 금융·테크 수요 풀 확장에 긍정적 영향을 줍니다. - 부산역... ',
#    'bloggername': '✅ 킹스마겐 공식블로그(부동산종합서비스기업)',
#    'bloggerlink': 'blog.naver.com/thekings0104',
#    'postdate': '20251015'},
#   {'title': '수협은행 기업인터넷뱅킹 바로가기와 이용 방법',
#    'link': 'https://ilovefamily.tistory.com/530',
#    'description': '또한, <b>핀테크</b> 기업과의 협력을 통해 새로운 비즈니스 모델을 창출하려는 시도가 더욱 활발해질... 향후 전망은 인공지능, 블록체인, 그리고 <b>핀테크</b> 기술과의 융합을 통해 더욱 스마트하고 안전한 금융 서비스... ',
#    'bloggername': '과거,현재,미래, 그리고 나.',
#    'bloggerlink': 'https://ilovefamily.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '블록체인을 이용한 조각투자(2025년 10월 13일 / 월)',
#    'link': 'https://blog.naver.com/korea_sj_forum/224041752783',
#    'description': '안국동 다운타우너 등 총 11개 부동산 공모 프로젝트를 성공해 충청권 뿐만 아니라 수도권외 지역에서 유일한 <b>핀테크</b> 기업이 되었다. 미국도 실리콘밸리 외 시애틀에 아마존, 레드먼드에는 마이크로소프트가... ',
#    'bloggername': '한국과학저널리즘포럼(KoreaSJForum)',
#    'bloggerlink': 'blog.naver.com/korea_sj_forum',
#    'postdate': '20251015'},
#   {'title': '강하다! 양자컴퓨터 ✨리게티컴퓨팅(RGTI), 아이온큐... ',
#    'link': 'https://blog.naver.com/kidsdad/224041745910',
#    'description': 'JP모건투자 #주가상승 #ETF #신기술 #글로벌증시 #AI융합 #탄소중립 #신약개발 #에너지혁신 #첨단기술 #NASDAQ #나스닥 #퀀텀점프 #주식투자 #시가총액 #장기투자 #<b>핀테크</b> #미래산업 #기술혁신 #기관투자 #테마주',
#    'bloggername': '본투 ❤️ 아이(Kids)',
#    'bloggerlink': 'blog.naver.com/kidsdad',
#    'postdate': '20251015'},
#   {'title': "다날 주가전망 : 세계 최대 써클과 '빅딜'35조 시장 본격 선점!",
#    'link': 'https://blog.naver.com/vpbusiness/224041744858',
#    'description': '다날<b>핀테크</b>, 다날에프엔비 등 다수 자회사 보유 사업 모델 및 주요 서비스 -커머스, 결제 플랫폼... -블록체인,가상자산: 자회사 다날<b>핀테크</b>를 통해 암호화폐 “페이코인(Paycoin)” 발행 및 결제 연계.... ',
#    'bloggername': '상위 1% 트레이더들의 주식 코인 차트이야기',
#    'bloggerlink': 'blog.naver.com/vpbusiness',
#    'postdate': '20251015'},
#   {'title': '티머니모빌리티-한국관광공사, ‘여행가는 가을’ 캠페인... ',
#    'link': 'https://blog.naver.com/carmgz/224041743200',
#    'description': '한편, 티머니모빌리티는 ▲‘모빌리티 <b>핀테크</b>&amp;플랫폼’ 전문기업으로 경쟁력을 강화하여 대중교통 중심 통합이동 서비스를 활성화하고, ▲전략적 제휴 및 투자 유치를 통해 새로운 성장 모멘텀을 확보해... ',
#    'bloggername': '카매거진 공식 블로그',
#    'bloggerlink': 'blog.naver.com/carmgz',
#    'postdate': '20251015'},
#   {'title': '농협카드 단기대출 급전 필요할 때 활용하는 방법',
#    'link': 'https://think-tank.tistory.com/893',
#    'description': '<b>핀테크</b> 기업들의 공세적인 마케팅과 간편한 대출 절차는 기존 금융권에 긴장감을 불어넣었으며, 플랫폼... 또한, <b>핀테크</b> 기업과의 경쟁 심화에 따른 과도한 마케팅 경쟁을 지양하고, 건전한 금융 생태계를... ',
#    'bloggername': 'think-tank.tistory.com',
#    'bloggerlink': 'https://think-tank.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '서울대 경영학과 – 글로벌 비즈니스 리더를 꿈꾸는 첫 걸음',
#    'link': 'https://blog.naver.com/sepsis6369/224040989777',
#    'description': 'IT플랫폼, <b>핀테크</b>, ESG컨설팅, 마케팅에이전시 창업 등 학문 및 연구분야 : 서울대·연세대·해외 MBA 진학, 경영학 연구자 최근에는 데이터경영·ESG·글로벌전략 분야의 중요성이 커지면서... ',
#    'bloggername': '과외선생님 추천',
#    'bloggerlink': 'blog.naver.com/sepsis6369',
#    'postdate': '20251015'},
#   {'title': 'UI 디자인 출원, 화면 디자인도 이제는 ‘권리’로 보호하세요',
#    'link': 'https://blog.naver.com/haandyoo/224039878440',
#    'description': '최근에는 AI·<b>핀테크</b>·모빌리티·의료 플랫폼까지 다양한 분야에서 UI가 곧 “브랜드 정체성”으로... 하앤유 특허법률사무소는 IT·모바일·<b>핀테크</b> 분야의 UI 디자인 보호 경험이 풍부한 변리사들이 함께하고... ',
#    'bloggername': '하앤유 특허법률사무소',
#    'bloggerlink': 'blog.naver.com/haandyoo',
#    'postdate': '20251015'},
#   {'title': '⚡ 양자컴퓨터 관련주 테마 폭등! JP모건 1조5천억 투자... ',
#    'link': 'https://blog.naver.com/zkfldb888/224041682620',
#    'description': '중 <b>핀테크</b> 확장 이들 기업은 정부의 ‘양자안보 통신망 구축사업’ 과 연계되어 있으며, 양자암호통신(QKD) 과 양자난수생성(QRNG) 기술을 통해 국가 통신 보안 체계의 핵심 인프라로 자리잡고 있습니다.... ',
#    'bloggername': '주식하는 남자 쿠니네',
#    'bloggerlink': 'blog.naver.com/zkfldb888',
#    'postdate': '20251015'},
#   {'title': '캐시우드 포트폴리오 TOP100 ㅡ PEG를 통해 저평가 주식... ',
#    'link': 'https://blog.naver.com/pureum123/224040669861',
#    'description': '29  신흥국 <b>핀테크</b>와 데이터 인프라 기업들이 주로 포함되네요. 특히 누홀딩스(NU), 푸투... 한쪽엔 저평가된 신흥국 <b>핀테크</b>(NU, FUTU) 다른 한쪽엔 “밸류가 뭐죠?” 하는 클라우드주(NET... ',
#    'bloggername': '푸르밍 재테크 일기장',
#    'bloggerlink': 'blog.naver.com/pureum123',
#    'postdate': '20251015'},
#   {'title': '기업은행, 정부의 금고이자 배당통로…밸류업 숨은 핵심주',
#    'link': 'https://blog.naver.com/kyending/224041737603',
#    'description': "최근에는 <b>핀테크</b> 제휴, AI 기반 신용평가 모델, 중소기업 전용 금융 플랫폼 등 디지털 전환에도 속도를 내고 있다. 전통적으로 정부와 산업은행, 수출입은행과 함께 '정책 3은행'으로 분류된다. 경쟁력... ",
#    'bloggername': '세상 돋보기 +0.75',
#    'bloggerlink': 'blog.naver.com/kyending',
#    'postdate': '20251015'},
#   {'title': '급전 필요할 땐? 2금융권 무서류 당일 대출, 똑똑하게 이용하는... ',
#    'link': 'https://blog.naver.com/kkimania/224041735668',
#    'description': '특히 토스와 같은 <b>핀테크</b> 플랫폼에서는 여러 2금융권의 대출 상품을 한눈에 비교하고 신청할 수 있어 편리합니다. 가정주부나 소득 증빙이 어려운 프리랜서도 신용카드 사용 내역 등을 통해 대출을 받을 수 있는... ',
#    'bloggername': 'kkimania님의블로그',
#    'bloggerlink': 'blog.naver.com/kkimania',
#    'postdate': '20251015'},
#   {'title': '대출 진행 시 필수 확인해야 할 금융정보 모음',
#    'link': 'https://sibauchi.tistory.com/1155',
#    'description': '<b>핀테크</b> 기업들은 AI 기반 신용 평가 모델을 개발하여 대출 심사의 정확성을 높이고, 맞춤형 대출 상품을 제공하는 데 주력하고 있습니다. 소비자들은 금리 변동에 대한 위험을 줄이기 위해 고정 금리 대출이나... ',
#    'bloggername': "Falconer's Teatime :: 이제는 말하고 말겠다-라멘토 비평",
#    'bloggerlink': 'https://sibauchi.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '더존비즈온(Duzon Bizon) 기업분석 및 투자포인트',
#    'link': 'https://blog.naver.com/techjay/224041691443',
#    'description': '<b>핀테크</b>/데이터: 자동전표·매입/매출 수집, 기업 신용/데이터 서비스, 비용관리. 보안·인프라... 데이터·<b>핀테크</b> 연계: 금융기관/PG사·법인카드 데이터 연동으로 비용·정산 자동화와 현금흐름 가시성 개선... ',
#    'bloggername': 'TechTag',
#    'bloggerlink': 'blog.naver.com/techjay',
#    'postdate': '20251015'},
#   {'title': '엔젤로보틱스(55900) +17.74% 급등 - 소프트뱅크 ABB 로봇... ',
#    'link': 'https://blog.naver.com/ai_invest/224041726290',
#    'description': "금융위원회, '코리아 <b>핀테크</b> 위크 2025' 개최 ✅ 2025-12: '국제 AI 표준 서밋' 한국 개최 ✅ 2026-01-06: CES 2026(국제전자제품박람회) 개최 ▶ 투자 전략 ✅ 단기: 로봇 테마 모멘텀으로 단기 강세... ",
#    'bloggername': '미래투자랩',
#    'bloggerlink': 'blog.naver.com/ai_invest',
#    'postdate': '20251015'},
#   {'title': '무서류 무방문 대출 간편 신청방법과 승인사례 확인',
#    'link': 'https://lefthusband.tistory.com/1548',
#    'description': '금리 인상과 경기 침체 우려 속에서도 <b>핀테크</b> 기업들의 혁신적인 기술 도입과 금융기관의 디지털 전환... <b>핀테크</b> 기업들은 빅데이터 분석을 통해 고객의 금융 상황과 니즈를 정확하게 파악하고, 이에 맞는... ',
#    'bloggername': 'fgwaff',
#    'bloggerlink': 'https://lefthusband.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '[돈나무] “ChatGPT에서 바로 쇼핑한다! 월마트가 연 AI... ',
#    'link': 'https://blog.naver.com/kang760302/224041724293',
#    'description': '2% AI 커머스와 <b>핀테크</b> 융합 수혜 IBUY (Amplify Online Retail ETF) ETSY, MELI, EBAY, AMZN +6.5% ChatGPT 쇼핑 테마 수혜 가능 FDN (Internet Index ETF) META, GOOG, SHOP, AMZN +5.9% AI 검색과 커머스 융합형 ETF ETF... ',
#    'bloggername': '돈나무 Money Tree',
#    'bloggerlink': 'blog.naver.com/kang760302',
#    'postdate': '20251015'},
#   {'title': '햇살론15 특례보증 신청자격과 준비서류 완벽정리',
#    'link': 'https://think-tank.tistory.com/919',
#    'description': '은행들은 리스크 관리에 더욱 집중하며 대출 심사를 강화하는 추세이며, <b>핀테크</b> 기업들은 자체... 이를 해결하기 위해 정부는 금리 인하 및 신청 절차 간소화를 추진하고 있으며, <b>핀테크</b> 기업들은 온라인... ',
#    'bloggername': 'think-tank.tistory.com',
#    'bloggerlink': 'https://think-tank.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '월마트, OpenAI와 손잡고 챗GPT에서 쇼핑 기능 제공',
#    'link': 'https://blog.naver.com/gatewaypla/224041720925',
#    'description': '외부 근거: 최근 금융권에서는 JP모건이 자체 AI 모델 개발과 동시에 다수의 AI <b>핀테크</b> 스타트업에 투자 및 파트너십을 체결하고 있으며, 미디어 분야에서는 AP통신, 악셀 스프링거 등이 OpenAI와 콘텐츠... ',
#    'bloggername': '인내와자유',
#    'bloggerlink': 'blog.naver.com/gatewaypla',
#    'postdate': '20251015'},
#   {'title': '토스뱅크 사장님 대출 금리 한도, 사업자 자격 총정리',
#    'link': 'https://ilovefamily.tistory.com/548',
#    'description': 'AI 기반 신용 평가 모델 도입, <b>핀테크</b> 기업과의 협력 강화, ESG 경영 확산 등이 주요 전략으로 꼽힙니다. 소비자는 금리 변동에 민감하게 반응하며, 정책 자금 활용과 <b>핀테크</b> 플랫폼 비교 분석을 통해 유리한 대출... ',
#    'bloggername': '과거,현재,미래, 그리고 나.',
#    'bloggerlink': 'https://ilovefamily.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '케이뱅크 사업자대출 신청자격과 금리 혜택 총정리',
#    'link': 'https://sibauchi.tistory.com/1141',
#    'description': '그리고 <b>핀테크</b> 기업의 성장이라는 세 가지 주요 요인에 의해 크게 변화했습니다. 금리 인상은... 반면, 케이뱅크를 포함한 <b>핀테크</b> 기업들은 비대면 대출 서비스를 통해 접근성을 높이며 시장 점유율을... ',
#    'bloggername': "Falconer's Teatime :: 이제는 말하고 말겠다-라멘토 비평",
#    'bloggerlink': 'https://sibauchi.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '아르헨티나 전력사 CEPU, OpenAI가 지원하는 데이터센터에... ',
#    'link': 'https://blog.naver.com/gatewaypla/224041718497',
#    'description': '클라우드 서비스의 품질 향상, 지연 시간(latency) 감소 등은 MercadoLibre의 이커머스 및 <b>핀테크</b> 사업 운영 효율성을 높이고 미래 성장을 위한 견고한 기반이 될 수 있습니다.',
#    'bloggername': '인내와자유',
#    'bloggerlink': 'blog.naver.com/gatewaypla',
#    'postdate': '20251015'}]}

# %% [markdown]
# # 네이버 API에서 수집 가능한 최대 자료 모두 수집하기

# %%
start_num = 1
for i in range(1, 11):
    if start_num < 901:
        start_num += 100
        print(start_num)
    elif start_num >= 901:
        start_num += 99
        print(start_num)

# %%
# while 문을 이용해야 함
page = 1
if response['total'] // 100 > 10:
    page = 10
else:
    page = response['total'] // 100+1

# %%
99 // 100 +1

# %% [markdown]
# # for문을 이용해 최대한 수집하기
# * naver api는 start 파라미터 최대값 1000
# * 1페이지당 100개씩 수집시 최대 11페이지까지 수집 가능

# %%
from dotenv import load_dotenv
import os
load_dotenv(dotenv_path="./data/.env_naver")
import requests

num = 1
all_data = []
for page in range(11):
    user_id = os.getenv("user_Id")
    user_secret= os.getenv("user_Secret")
    url = "https://openapi.naver.com/v1/search/blog"
    keyword ="핀테크"
    payload = dict(query=keyword, display=100, start=num, sort="date")
    headers = {"X-Naver-Client-Id" : user_id, "X-Naver-Client-Secret" : user_secret} 
    r = requests.get(url, params=payload, headers=headers)
    print(r.url)
    print(r.status_code)
    response = r.json()
    all_data.append(pd.DataFrame(response['items']))
    
    if num < 901:
        num+= 100
    elif num >= 901:
        num += 99
    print(num)

# %%
final_result = pd.concat(all_data)
final_result

# %% [markdown]
# # while문을 이용해서 수집 페이지까지 자동화 하기

# %%
from dotenv import load_dotenv
import os
load_dotenv(dotenv_path="./data/.env_naver")
import requests

total_page = 1
page = 1
num = 1

all_data = []
while page <= total_page:
    user_id = os.getenv("user_Id")
    user_secret= os.getenv("user_Secret")
    url = "https://openapi.naver.com/v1/search/blog"
    keyword ="핀테크"
    payload = dict(query=keyword, display=100, start=num, sort="date")
    headers = {"X-Naver-Client-Id" : user_id, "X-Naver-Client-Secret" : user_secret} 
    r = requests.get(url, params=payload, headers=headers)
    print(r.url)
    print(r.status_code)
    response = r.json()
    all_data.append(response['items'])

    # 전체 페이지 계산
    if response['total'] // 100 > 11:
        total_page = 11
    else:
        total_page = response['total'] // 100 + 1
        
    # page 증가
    page += 1
    
    # num이 1000되도록
    if num < 901:
        num+= 100
    elif num >= 901:
        num += 99

# %%
len(all_data)

# %%
all_data[2]

# %%
import re
def text_clean(text):
    # HTML 태그를 없애는 정규표현식
    result = re.sub(r"</?[^>]+>", "", text)
    # 한글, 영문, 숫자 외의 모든 문자 제거 후 공백으로 변환
    result = re.sub(r"[^가-힣a-zA-Z0-9]", " ", result)
    result = result.replace("  ", " ").replace("  ", " ").replace("  ", " ")
    return result

# %%
result = {}
for page in all_data:
    for item in page:
        for key, value in item.items():
            if key in ["title", "description"]:
                result.setdefault(key, []).append(text_clean(value))
            else:
                result.setdefault(key, []).append(value)
final_df = pd.DataFrame(result)
final_df

# %%
final_df.to_csv("./data/네이버api수집1100개.csv", index=False, encoding="utf-8-sig")
