# %% [markdown]
# # 🌳 의사결정나무, 배깅, 부스팅의 차이
#
# ---
#
# ## 1️⃣ 의사결정나무 (Decision Tree)
#
# 의사결정나무는 **질문을 따라가며 답을 찾는 구조의 모델**이다.
# 사람이 어떤 결정을 내릴 때처럼, “질문”을 하나씩 던지며
# 조건에 따라 **결과를 단계적으로 선택하는 방식**이다.
#
# ```
# 예를 들어, “오늘 우산을 가져갈까?”라는 문제를 생각해 보자.
#
# 하늘에 구름이 많은가? → 예
# ↓
#
# 일기예보에서 비가 온다고 했는가? → 예
# ↓
# 👉 우산을 가져간다.
# ```
#
# 이처럼 **질문을 분기하며 조건에 따라 결론을 내리는 구조**가
# 바로 의사결정나무이다.
# 나무의 “가지(branch)”를 따라가다 보면 마지막 “잎(leaf)”에서 결론이 나온다.
#
# 하지만 트리가 하나뿐이라,
# 데이터가 조금만 달라져도 나무 모양이 크게 바뀌는 단점이 있다.
# 즉, **데이터에 너무 민감하고 과적합(Overfitting)**이 잘 일어나는 모델이다.
#
# 👉 **요약**
# - 장점: 이해하기 쉽고, 결정 이유를 설명하기 쉽다.
# - 단점: 데이터에 민감하고, 과적합이 잘 일어난다.
#
# ---
#
# ## 2️⃣ 배깅 (Bagging)
#
# 배깅은 “Bootstrap Aggregating”의 줄임말이다.
# 의사결정나무 한 그루로는 불안정하기 때문에,
# **여러 그루의 나무를 동시에 학습시켜 결과를 합치는 방법**이다.
#
# 즉, 원래 데이터를 여러 번 섞어서 나눈 뒤
# 각 나무가 조금씩 다른 데이터를 보고 학습하도록 한다.
# 이렇게 학습한 나무들이 **투표(분류)**나 **평균(회귀)**으로 결과를 내린다.
#
# 예를 들어 “오늘 비가 올까?”라는 질문을
# 세 그루의 나무에게 물어보면 다음과 같이 될 수 있다.
# ```
# 나무1: 비가 올 것이다 ☔
# 나무2: 비가 안 올 것이다 ☀️
# 나무3: 비가 올 것이다 ☔
# → 다수결 결과: 비가 올 것이다 ☔
# ```
#
# 이렇게 여러 나무가 함께 결정하기 때문에
# 한 나무가 틀리더라도 전체 결과는 안정적이다.
# 즉, **과적합이 줄고, 예측이 더 안정적**이 된다.
#
# 배깅의 대표적인 알고리즘은 **랜덤 포레스트(Random Forest)**이다.
# 이 방법은 “숲(forest)”처럼 여러 나무가 협력해서 예측을 하는 모델이다.
#
# 👉 **요약**
# - 장점: 안정적이고, 과적합이 줄어든다.
# - 단점: 계산이 많고, 해석이 어렵다.
#
# ---
#
# ## 3️⃣ 랜덤포레스트 (Random Forest)
#
# 랜덤포레스트는 **배깅(Bagging)**의 대표적인 알고리즘이다.
# 즉, 여러 개의 의사결정나무를 만들어 **숲(forest)**처럼 사용하는 방법이다. 🌲🌲🌲
#
# 배깅과 비슷하지만 한 가지 차이가 있다.
# 랜덤포레스트는 **데이터뿐만 아니라, 사용할 특성(열)**도
# 무작위로 일부만 선택해서 학습한다.
#
# 예를 들어,
# 나무마다 “하늘 상태”, “기온”, “습도”, “바람 세기” 중
# 무작위로 몇 가지 정보만 보고 판단하도록 하는 것이다.
#
# 이렇게 하면 각 나무가 **조금씩 다른 관점**에서 배우게 되어,
# 서로 비슷하게 틀릴 가능성이 줄어든다.
# 그 결과, 전체 숲의 예측이 더욱 안정적이 된다.
#
# 👉 **요약**
# - 배깅을 발전시킨 방법으로, 데이터와 특성을 모두 무작위로 사용한다.
# - 여러 나무가 협력하므로 예측이 안정적이고 강력하다.
# - 대표적인 앙상블(ensemble) 알고리즘이다.
#
# 👉 **비유**
# - 한 나무(Decision Tree)는 **혼자 판단하는 친구**이다.
# - 여러 나무가 모인 랜덤포레스트는 **서로 다른 의견을 모아 다수결로 결정하는 반 친구들 모임**이다.
#
# ---
#
# ## 4️⃣ 부스팅 (Boosting)
#
# 부스팅은 “여러 나무가 순서대로 배우며, 이전의 실수를 보완하는 방법”이다.
# 즉, **앞의 모델이 틀린 부분을 다음 모델이 집중해서 학습**한다.
#
# 예를 들어 공부할 때 틀린 문제를 복습하는 것과 같은 원리이다.
# 첫 번째 모델이 만든 오차를 두 번째 모델이 고치고,
# 두 번째 모델의 실수를 세 번째 모델이 보완하는 식이다.
#
# 이 과정을 반복하면 모델은 점점 더 똑똑해지고 정확해진다.
# 하지만 너무 많이 반복하면, 훈련 데이터에만 맞춰 외우는 **과적합**이 생길 수 있다.
#
# 대표적인 알고리즘에는 **XGBoost**, **LightGBM**, **CatBoost** 등이 있다.
#
# 👉 **요약**
# - 장점: 학습을 반복할수록 예측력이 높아진다.
# - 단점: 너무 많이 학습하면 외우기만 해서 과적합이 생길 수 있다.
#
# ---
#
# ## ⚖️ 5️⃣ 네 가지 방법의 비교표
#
# | 구분 | 의사결정나무 | 배깅(Bagging) | 랜덤포레스트(Random Forest) | 부스팅(Boosting) |
# |------|---------------|----------------|------------------------------|-------------------|
# | 학습 방식 | 하나의 나무로 예측 | 여러 나무가 병렬로 학습 | 여러 나무가 병렬로 학습 (특성도 무작위) | 여러 나무가 순서대로 학습 |
# | 학습 관계 | 독립적 | 독립적 | 독립적 | 서로 의존함 |
# | 목표 | 단순한 규칙으로 예측 | 결과를 평균하여 안정화 | 무작위성으로 다양성 확보 + 안정화 | 이전 실수를 보완하며 정확도 향상 |
# | 장점 | 이해 쉬움 | 과적합 완화, 안정적 | 성능 높고 안정적 | 예측력 매우 높음 |
# | 단점 | 과적합 쉬움 | 느리고 복잡 | 계산량 많음 | 튜닝 어렵고 과적합 가능 |
#
# ---
#
# ## 🌟 6️⃣ 비유로 정리
#
# - **의사결정나무**는 **혼자 판단하는 친구**이다.
# - **배깅**은 **서로 다른 친구들이 각자 생각한 뒤 투표하는 모둠**이다.
# - **랜덤포레스트**는 **서로 다른 시각(정보)으로 판단하는 친구들의 숲**이다.
# - **부스팅**은 **앞의 실수를 복습하면서 점점 똑똑해지는 학생**이다.
#
# ---
#
# ## 🎯 7️⃣ 한 문장 요약
#
# > 의사결정나무는 “하나의 나무로 판단하는 모델”이고,
# > 배깅은 “여러 나무가 함께 투표하는 방법”이며,
# > 랜덤포레스트는 “배깅을 발전시켜 더 다양한 시각에서 판단하는 숲”이고,
# > 부스팅은 “이전 실수를 점점 고쳐가며 발전하는 학습 방법”이다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %% [markdown]
# #### 분석목적: 학력, 교육연수, 혼인상태, 직업정보가 있는 연봉데이터셋을 이용해 연봉 예측하기
# * 연봉이 5만달러 이상인지 아닌지
# * age: 나이
# * workclass: 고용형태
# * education: 학력
# * education-num: 교육연수
# * marital-status: 혼인상태
# * occupation: 직업
# * relationship: 가족관계
# * race: 인종
# * sex: 성별
# * capital-gain: 자산증가
# * capital-loss: 자산감소
# * hours-per-week: 주당 노동 시간
# * native-country: 본국
# * class: 연봉구분 - target(분석대상)

# %%
data = pd.read_csv("./data/salary2.csv")
data.head()
# Out:
#    age   workclass      education  education-num       marital-status  \
# 0   25     Private           11th              7        Never-married
# 1   38     Private        HS-grad              9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm             12   Married-civ-spouse
# 3   44     Private   Some-college             10   Married-civ-spouse
# 4   18         NaN   Some-college             10        Never-married
#
#            occupation relationship    race      sex  capital-gain  \
# 0   Machine-op-inspct    Own-child   Black     Male             0
# 1     Farming-fishing      Husband   White     Male             0
# 2     Protective-serv      Husband   White     Male             0
# 3   Machine-op-inspct      Husband   Black     Male          7688
# 4                 NaN    Own-child   White   Female             0
#
#    capital-loss  hours-per-week  native-country   class
# 0             0              40   United-States   <=50K
# 1             0              50   United-States   <=50K
# 2             0              40   United-States    >50K
# 3             0              40   United-States    >50K
# 4             0              30   United-States   <=50K

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       46043 non-null  object
#  2   education       48842 non-null  object
#  3   education-num   48842 non-null  int64
#  4   marital-status  48842 non-null  object
#  5   occupation      46033 non-null  object
#  6   relationship    48842 non-null  object
#  7   race            48842 non-null  object
#  8   sex             48842 non-null  object
#  9   capital-gain    48842 non-null  int64
#  10  capital-loss    48842 non-null  int64
#  11  hours-per-week  48842 non-null  int64
#  12  native-country  47985 non-null  object
#  13  class           48842 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 5.2+ MB

# %%
data.describe()
# Out:
#                 age  education-num  capital-gain  capital-loss  hours-per-week
# count  48842.000000   48842.000000  48842.000000  48842.000000    48842.000000
# mean      38.643585      10.078089   1079.067626     87.502314       40.422382
# std       13.710510       2.570973   7452.019058    403.004552       12.391444
# min       17.000000       1.000000      0.000000      0.000000        1.000000
# 25%       28.000000       9.000000      0.000000      0.000000       40.000000
# 50%       37.000000      10.000000      0.000000      0.000000       40.000000
# 75%       48.000000      12.000000      0.000000      0.000000       45.000000
# max       90.000000      16.000000  99999.000000   4356.000000       99.000000

# %% [markdown]
# 결측값 처리

# %%
data.isna().sum() / len(data) * 100
# Out:
# age               0.000000
# workclass         5.730724
# education         0.000000
# education-num     0.000000
# marital-status    0.000000
# occupation        5.751198
# relationship      0.000000
# race              0.000000
# sex               0.000000
# capital-gain      0.000000
# capital-loss      0.000000
# hours-per-week    0.000000
# native-country    1.754637
# class             0.000000
# dtype: float64

# %% [markdown]
# workclass, occupation, native-country 대치

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'class'],
#       dtype='object')

# %%
data['occupation'] = data['occupation'].fillna(data['occupation'].mean)

# %%
data['workclass'] = data['workclass'].fillna(data['workclass'].mean)

# %%
data['native-country'].value_counts()
# Out:
# native-country
# United-States                 43832
# Mexico                          951
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Nicaragua                        49
# Greece                           49
# Peru                             46
# Ecuador                          45
# France                           38
# Ireland                          37
# Thailand                         30
# Hong                             30
# Cambodia                         28
# Trinadad&Tobago                  27
# Laos                             23
# Outlying-US(Guam-USVI-etc)       23
# Yugoslavia                       23
# Scotland                         21
# Honduras                         20
# Hungary                          19
# Holand-Netherlands                1
# Name: count, dtype: int64

# %%
data['native-country'] = data['native-country'].fillna(data['native-country'].mode()[0])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       48842 non-null  object
#  2   education       48842 non-null  object
#  3   education-num   48842 non-null  int64
#  4   marital-status  48842 non-null  object
#  5   occupation      48842 non-null  object
#  6   relationship    48842 non-null  object
#  7   race            48842 non-null  object
#  8   sex             48842 non-null  object
#  9   capital-gain    48842 non-null  int64
#  10  capital-loss    48842 non-null  int64
#  11  hours-per-week  48842 non-null  int64
#  12  native-country  48842 non-null  object
#  13  class           48842 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 5.2+ MB

# %% [markdown]
# 수치형: age,education-num, capital-gain, capital-loss, hours-per-week

# %% [markdown]
# 이상값 탐지

# %%
data.plot(kind='box')
# Out:
# <Axes: >

# %%
for col in ['age','education-num', 'capital-gain', 'capital-loss', 'hours-per-week']:
    data[col].plot(kind='box')
    plt.show()

# %%
data['capital-gain'].describe()
# Out:
# count    48842.000000
# mean      1079.067626
# std       7452.019058
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      99999.000000
# Name: capital-gain, dtype: float64

# %%
data['capital-loss'].describe()
# Out:
# count    48842.000000
# mean        87.502314
# std        403.004552
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       4356.000000
# Name: capital-loss, dtype: float64

# %%
cols_to_log = ['capital-gain', 'capital-loss']
data[cols_to_log] = data[cols_to_log].apply(np.log1p)
print(data[cols_to_log].describe())
# Out:
#        capital-gain  capital-loss
# count  48842.000000  48842.000000
# mean       0.728544      0.350973
# std        2.445480      1.586232
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      0.000000
# max       11.512925      8.379539

# %% [markdown]
# 변수간 상관관계 분석

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'class'],
#       dtype='object')

# %%
corr_result = data[['age','education-num', 'capital-gain', 'capital-loss', 'hours-per-week']].corr(method="spearman")
corr_result
# Out:
#                      age  education-num  capital-gain  capital-loss  \
# age             1.000000       0.063212      0.124436      0.057584
# education-num   0.063212       1.000000      0.118871      0.077017
# capital-gain    0.124436       0.118871      1.000000     -0.066328
# capital-loss    0.057584       0.077017     -0.066328      1.000000
# hours-per-week  0.146604       0.164437      0.091914      0.060063
#
#                 hours-per-week
# age                   0.146604
# education-num         0.164437
# capital-gain          0.091914
# capital-loss          0.060063
# hours-per-week        1.000000

# %%
plt.figure()
sns.heatmap(corr_result, annot=True, linewidths=1)
plt.show()

# %% [markdown]
# 종속변수와 독립변수 분리(학습 테스트 분리)

# %%
X = data.drop('class', axis=1)
y = data['class']

# %%
X
# Out:
#        age                                          workclass      education  \
# 0       25                                            Private           11th
# 1       38                                            Private        HS-grad
# 2       28                                          Local-gov     Assoc-acdm
# 3       44                                            Private   Some-college
# 4       18  <bound method Series.mean of 0              Pr...   Some-college
# ...    ...                                                ...            ...
# 48837   27                                            Private     Assoc-acdm
# 48838   40                                            Private        HS-grad
# 48839   58                                            Private        HS-grad
# 48840   22                                            Private        HS-grad
# 48841   52                                       Self-emp-inc        HS-grad
#
#        education-num       marital-status  \
# 0                  7        Never-married
# 1                  9   Married-civ-spouse
# 2                 12   Married-civ-spouse
# 3                 10   Married-civ-spouse
# 4                 10        Never-married
# ...              ...                  ...
# 48837             12   Married-civ-spouse
# 48838              9   Married-civ-spouse
# 48839              9              Widowed
# 48840              9        Never-married
# 48841              9   Married-civ-spouse
#
#                                               occupation relationship    race  \
# 0                                      Machine-op-inspct    Own-child   Black
# 1                                        Farming-fishing      Husband   White
# 2                                        Protective-serv      Husband   White
# 3                                      Machine-op-inspct      Husband   Black
# 4      <bound method Series.mean of 0         Machine...    Own-child   White
# ...                                                  ...          ...     ...
# 48837                                       Tech-support         Wife   White
# 48838                                  Machine-op-inspct      Husband   White
# 48839                                       Adm-clerical    Unmarried   White
# 48840                                       Adm-clerical    Own-child   White
# 48841                                    Exec-managerial         Wife   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country
# 0         Male      0.000000           0.0              40   United-States
# 1         Male      0.000000           0.0              50   United-States
# 2         Male      0.000000           0.0              40   United-States
# 3         Male      8.947546           0.0              40   United-States
# 4       Female      0.000000           0.0              30   United-States
# ...        ...           ...           ...             ...             ...
# 48837   Female      0.000000           0.0              38   United-States
# 48838     Male      0.000000           0.0              40   United-States
# 48839   Female      0.000000           0.0              40   United-States
# 48840     Male      0.000000           0.0              20   United-States
# 48841   Female      9.617471           0.0              40   United-States
#
# [48842 rows x 13 columns]

# %%
y
# Out:
# 0         <=50K
# 1         <=50K
# 2          >50K
# 3          >50K
# 4         <=50K
#           ...
# 48837     <=50K
# 48838      >50K
# 48839     <=50K
# 48840     <=50K
# 48841      >50K
# Name: class, Length: 48842, dtype: object

# %%
y.value_counts()
# Out:
# class
# <=50K    37155
# >50K     11687
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=42, stratify=y)

# %%
X_train.shape
# Out:
# (34189, 13)

# %%
X_test.shape
# Out:
# (14653, 13)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
data.dtypes
# Out:
# age                 int64
# workclass          object
# education          object
# education-num       int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# sex                object
# capital-gain      float64
# capital-loss      float64
# hours-per-week      int64
# native-country     object
# class              object
# dtype: object

# %%
cat_cols = ['workclass', 'education', 'marital-status', 'occupation',
            'relationship', 'race', 'sex', 'native-country']
X_train_ohe = pd.get_dummies(X_train, columns=cat_cols)
X_test_ohe = pd.get_dummies(X_test, columns=cat_cols)

# %%
X_test_ohe = X_test_ohe.reindex(columns=X_train_ohe.columns, fill_value=0)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder(drop='first', handle_unknown="ignore", sparse_output=False)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc_pruned = DecisionTreeClassifier(max_depth=3, random_state=42)
dtc_pruned.fit(X_train_ohe, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %% [markdown]
# 결정트리 시각화

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(22,12))
plot_tree()
